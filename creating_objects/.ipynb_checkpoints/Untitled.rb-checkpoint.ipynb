# %%
seed_stock = File.open("./files/seed_stock_data.tsv", "r")

puts seed_stock.methods
# Out:
# to_path
# path
# truncate
# flock
# lstat
# atime
# mtime
# ctime
# birthtime
# chmod
# chown
# size
# wait
# reopen
# syswrite
# sysread
# pread
# pwrite
# fileno
# fsync
# fdatasync
# sync
# sync=
# lineno
# lineno=
# readchar
# readbyte
# ungetbyte
# ungetc
# write
# tell
# seek
# raw
# raw!
# cooked
# rewind
# pos
# pos=
# eof
# eof?
# close_on_exec?
# close_on_exec=
# close
# closed?
# close_read
# close_write
# isatty
# tty?
# binmode?
# sysseek
# advise
# ioctl
# fcntl
# pid
# external_encoding
# internal_encoding
# set_encoding_by_bom
# autoclose?
# autoclose=
# console_mode
# console_mode=
# winsize=
# iflush
# cooked!
# getch
# echo=
# goto
# cursor
# read_nonblock
# cursor_up
# oflush
# ioflush
# beep
# goto_column
# erase_line
# cursor=
# scroll_forward
# cursor_down
# cursor_left
# cursor_right
# check_winsize_changed
# getpass
# erase_screen
# nonblock?
# nonblock=
# nonblock
# scroll_backward
# clear_screen
# pressed?
# stat
# echo?
# noecho
# <<
# getbyte
# winsize
# ...
